# %% [markdown]
# # 文档说明

# %% [markdown]
# 本文档重点补充了有关模型优化（即寻找最佳超参数）的一些内容。
#
# 对于模型融合而言，Datawhale已经给出较为详细的[notebook](https://tianchi.aliyun.com/notebook-ai/detail?spm=5176.12586969.1002.15.1cd8593aUpmrCG&postId=95535)，直接参考该文档即可。
#
# 模型融合是建立在模型调参的基础上，可以理解为多裁判评分机制（stacking要相对更复杂一些）。
#
# 其实，xgboost、lightgbm等集成模型本身也是模型融合的一种手段，相比于最终的融合而言，前期的特征工程以及模型调参更为重要。

# %% [markdown]
# # 模型调参及模型融合

# %% [markdown]
# 在机器学习中，优化模型意味着为特定问题找到最佳的超参数集

# %% [markdown]
# ## 超参数

# %% [markdown]
# 模型超参数定义[model hyperparameters are in contrast to model parameters](https://machinelearningmastery.com/difference-between-a-parameter-and-a-hyperparameter/) :
#
# * **模型超参数**被认为最好通过机器学习算法来进行设置，在训练之前由数据科学家调整。 例如，随机森林中的树木数量，或者K-Nearest Neighbors Regression中使用的邻居数量。
#
# * **模型参数**是模型在训练期间学习的内容，例如线性回归中的权重。
#
# 我们作为数据科学家通过**选择超参数**来控制模型，这些选择会对模型的最终性能产生显着影响（尽管通常不会像获取更多数据或工程特征那样有效）。调整模型超参数 [Tuning the model hyperparameters](http://scikit-learn.org/stable/modules/grid_search.html) 可以控制模型中欠拟合与过拟合的平衡。
#
# * 我们可以尝试通过制作**更复杂的模型**来校正欠拟合，例如在随机森林中使用更多树或在深度神经网络中使用更多层。 当我们的模型没有足够的容量（自由度）来学习特征和目标之间的关系时，模型会发生**欠拟合并且具有高偏差**。
# * 我们可以通过**限制模型的复杂度和应用正则化**来尝试纠正过度拟合。 这可能意味着降低多项式回归的次数，或将衰退层添加到深度神经网络。 **过拟合的模型具有高方差**并且实际上记住了训练集。
#
# **欠拟合和过拟合导致模型在测试集上的泛化性能变差**。
#
# 选择超参数的问题在于，没有放之四海而皆准的超参数。 因此，对于每个新数据集，我们必须找到最佳设置。 这可能是一个耗时的过程，但幸运的是，在Scikit-Learn中执行此过程有多种选择。更好的是，新的libraries，如epistasis实验室的[TPOT](https://epistasislab.github.io/tpot/) 旨在为你自动完成此过程！ 目前，我们将坚持在Scikit-Learn中手动（有点）这样做，但请继续关注自动模型选择的文章！
#
# __[常见设置超参数的做法有](https://www.jianshu.com/p/1b23afa34a47)__：
#
# 1. **猜测和检查**：根据经验或直觉，选择参数，一直迭代。
# 2. **网格搜索**：让计算机尝试在一定范围内均匀分布的一组值。
# 3. **随机搜索**：让计算机随机挑选一组值。
# 4. **贝叶斯优化**：使用贝叶斯优化超参数，会遇到贝叶斯优化算法本身就需要很多的参数的困难。
# 5. **在良好初始猜测的前提下进行局部优化**：这就是 MITIE 的方法，它使用 BOBYQA 算法，并有一个精心选择的起始点。由于 BOBYQA 只寻找最近的局部最优解，所以这个方法是否成功很大程度上取决于是否有一个好的起点。在 MITIE 的情下,我们知道一个好的起点，但这不是一个普遍的解决方案，因为通常你不会知道好的起点在哪里。从好的方面来说，这种方法非常适合寻找局部最优解。稍后我会再讨论这一点。
# 6. 最新提出的 **LIPO 的全局优化方法**。这个方法没有参数，而且经验证比随机搜索方法好。

# %% [markdown]
# ## Import

# %%
# 导入需要用到的工具包
# 用于数据操作的pandas和numpy
import pandas as pd
import numpy as np

# 不显示关于在切片副本上设置值的警告
pd.options.mode.chained_assignment = None

# 一个dataframe 最多显示60例样本
pd.set_option('display.max_columns', 60)

# 可视化工具包
import matplotlib.pyplot as plt
# %matplotlib inline

# 设置默认字体大小
plt.rcParams['font.size'] = 24

# 导入设置图片大小的工具
from IPython.core.pylabtools import figsize

# 导入用于可视化的Seaborn
import seaborn as sns
sns.set(font_scale = 2)

# 把数据分为训练集和测试集

from sklearn.model_selection import train_test_split

import math

# 导入xgb、lgb、catboost
import xgboost as xgb
import lightgbm as lgb
import catboost

## 参数搜索和评价的
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## 数据读取

# %%
## 通过Pandas对于数据进行读取 (pandas是一个很友好的数据读取函数库)
Train_data = pd.read_csv('used_car_train_20200313.csv', sep=' ')
TestA_data = pd.read_csv('used_car_testA_20200313.csv', sep=' ')

## 输出数据的大小信息
print('Train data shape:',Train_data.shape)
print('TestA data shape:',TestA_data.shape)
# Out:
# Train data shape: (150000, 31)
# TestA data shape: (50000, 30)

# %% [markdown]
# 凭借前期数据探索所做的工作，我们直接定义数据预处理函数

# %%
# 定义删除高共线性特征函数
def remove_collinear_features(x, threshold):
    '''
    Objective:
       删除数据帧中相关系数大于阈值的共线特征。 删除共线特征可以帮助模型泛化并提高模型的可解释性。

    Inputs: 
        阈值：删除任何相关性大于此值的特征

    Output: 
        仅包含非高共线特征的数据帧
    '''

    # 在数据副本上进行操作
    x = x.copy()

    # 仅对v_系列特征进行处理
    x_numeric = x[['v_0', 'v_1', 'v_2', 'v_3', 'v_4', 'v_5', 'v_6', 'v_7',
                    'v_8', 'v_9', 'v_10', 'v_11', 'v_12', 'v_13', 'v_14']]


    # 计算相关性矩阵
    corr_matrix = x_numeric.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # 迭代相关性矩阵并比较相关性
    for i in iters:
        for j in range(i):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)

            # 如果相关性超过阈值
            if val >= threshold:
                # 打印有相关性的特征和相关值
                # print(col.values[0], "|", row.values[0], "|", round(val[0][0], 3))
                drop_cols.append(col.values[0])

    # 删除每对相关列中的一个
    drops = set(drop_cols)
    x = x.drop(columns = drops)

    return x

# %%
def data_processing(df, threshold):
    '''
    Objective:
        对输入的DataFrame数据进行预处理，处理依据在前期EDA中获得。
        
    Inputs:
        df: 输入的原始DataFrame数据
        threshold: 用于删除数据中高共线性特征，当相关系数大于该阈值时，进行删除
    
    Outputs：
        输出经过预处理后的DataFrame数据
    '''
    Output = df.copy()
    
    # 类别型特征
    category_cols = ['brand', 'bodyType', 'fuelType', 'gearbox', 'notRepairedDamage']
    
    
    # 修正缺失值，有些缺失值为' - '，将其替换为np.nan
    Output.replace('-', np.nan, inplace=True)
    
    # 将"Not Available" 项替换为可以解释为浮点数的np.nan
    Output.replace({'Not Available': np.nan}, inplace=True)

    # 加入一列用于统计样本缺失值总数
    Output['miss_info'] = Output.isnull().sum(axis=1)

    # 转换某些列的数据类型
    for col in list(Output.columns):
        # 选择需要被数字化的列，通过if判断实现
        # 凡是包含下列红色字体的列，都是需要被转换的列
        if ('notRepairedDamage' in col):
            # 将数据类型转换为float
            Output[col] = Output[col].astype(float)
    
    # 添加used_time特征列
    Output['used_time'] = (pd.to_datetime(Output['creatDate'], format='%Y%m%d', errors='coerce') - 
                            pd.to_datetime(Output['regDate'], format='%Y%m%d', errors='coerce')).dt.days
    
    
    # 删除高线性特征
    Output = remove_collinear_features(Output, threshold=threshold)
    
    # 处理类别型特征
    # data_notRepairedDamage = pd.get_dummies(Output['notRepairedDamage'], prefix='notRepairedDamage', dummy_na=True)
    # data_fuelType = pd.get_dummies(Output['fuelType'], prefix='fuelType', dummy_na=True)
    # data_gearbox = pd.get_dummies(Output['gearbox'], prefix='gearbox', dummy_na=True)
    # data_bodyType = pd.get_dummies(Output['bodyType'], prefix='bodyType', dummy_na=True)
    
    # Output = pd.concat([Output, data_notRepairedDamage, data_fuelType, data_gearbox, data_bodyType], axis=1)
    

    
    # 处理类别型特征
    
    
    # 删除多余特征
    del Output["seller"]
    del Output["offerType"]
    del Output['name']
    del Output['model']
    del Output['regionCode']
    del Output['regDate']
    #del Output['brand']
    #del Output['bodyType']
    #del Output['fuelType']
    #del Output['gearbox']
    #del Output['notRepairedDamage']
    del Output['creatDate']
    
    return Output

# %%
Train_data = data_processing(Train_data, threshold=0.9)
TestA_data = data_processing(TestA_data, threshold=0.9)

## 输出数据的大小信息
print('Train data shape:',Train_data.shape)
print('TestA data shape:',TestA_data.shape)
# Out:
# Train data shape: (150000, 19)
# TestA data shape: (50000, 18)

# %% [markdown]
# ## 特征与标签构建

# %% [markdown]
# 设计思路如下：
#  * 将训练样本划分为两大类，一类是类别型特征，一类是仅包含数值型特征
#  * 同时，对数值型特征样本的数据又划分包含`used_time`信息与不包含`used_time`信息
#  * 使用catboost对类别型特征做回归分析；使用xgb和lgb对数值型特征做回归分析
#  * 最后进行模型融合

# %%
# 定义一个构建数据集的函数，方便以后调用

def split_data(df, flag=0):
    '''
    Objective:
        将数据集按要求划分成四类：1. 所有类别型特征集（不论是否缺失`used_time`）；2. 包含`used_time`信息的数值型特征集
                                                            3. 不含`used_time`信息的数值型特征集；
    
    Input:
        待划分的DataFrame数据
        
    Output:
        四类特征数据集：O_1, O_2, O_3, O_4
    
    flag: 0表示划分训练集；1表示划分测试集，默认为0
    '''
#     category_features = ['SaleID', 'notRepairedDamage_0.0', 'notRepairedDamage_1.0', 'notRepairedDamage_nan',
#                         'fuelType_0.0', 'fuelType_1.0', 'fuelType_2.0', 'fuelType_3.0', 'fuelType_4.0', 'fuelType_5.0',
#                         'fuelType_6.0', 'fuelType_nan', 'gearbox_0.0', 'gearbox_1.0', 'gearbox_nan', 'bodyType_0.0',
#                         'bodyType_1.0', 'bodyType_2.0', 'bodyType_3.0', 'bodyType_4.0', 'bodyType_5.0', 'bodyType_6.0',
#                         'bodyType_7.0', 'bodyType_nan', 'price']
    
    category_features = ['SaleID', 'brand', 'bodyType', 'fuelType', 'gearbox', 'notRepairedDamage']
    
    value_features = ['SaleID', 'power', 'kilometer', 'v_0', 'v_1', 'v_2', 'v_3', 'v_4', 'v_11',
                     'v_12', 'v_14', 'used_time', 'miss_info']
    
    O_1 = df.copy()
    O_1.replace(np.nan, 'missing', inplace=True)
    O_1['brand'] = O_1['brand'].astype('str')
    O_1 = O_1.drop('used_time', axis=1)
    
    has_time = df.loc[df['used_time'].notna()]    
    O_2 = has_time[value_features]
    
    no_time = df.loc[df['used_time'].isna()]    
    O_3 = no_time[value_features]
    
    # 因为O_3明确缺失`used_time`，所以对应的`mis_info`应减1
    O_3['miss_info'].apply(lambda x: x -1 if x >0 else x)
    
    # 删除O_3中特征`used_time`列
    O_3.drop('used_time', axis=1, inplace=True)
    
    if flag == 0:
        O_1['price'] = df['price']
        O_2['price'] = has_time['price']
        O_3['price'] = no_time['price']
    
    return O_1, O_2, O_3

# %%
Train_data_1, Train_data_2, Train_data_3 = split_data(Train_data, flag=0)

Test_data_1, Test_data_2, Test_data_3 = split_data(TestA_data, flag=1)

# %%
Test_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 17 columns):
# SaleID               50000 non-null int64
# brand                50000 non-null object
# bodyType             50000 non-null object
# fuelType             50000 non-null object
# gearbox              50000 non-null object
# power                50000 non-null int64
# kilometer            50000 non-null float64
# notRepairedDamage    50000 non-null object
# v_0                  50000 non-null float64
# v_1                  50000 non-null float64
# v_2                  50000 non-null float64
# v_3                  50000 non-null float64
# v_4                  50000 non-null float64
# v_11                 50000 non-null float64
# v_12                 50000 non-null float64
# v_14                 50000 non-null float64
# miss_info            50000 non-null int64
# dtypes: float64(9), int64(3), object(5)
# memory usage: 6.5+ MB

# %% [markdown]
# 查看划分得到的数据集，确认划分无误。

# %%
# 查看第一部分，所有类别型特征集
Train_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 18 columns):
# SaleID               150000 non-null int64
# brand                150000 non-null object
# bodyType             150000 non-null object
# fuelType             150000 non-null object
# gearbox              150000 non-null object
# power                150000 non-null int64
# kilometer            150000 non-null float64
# notRepairedDamage    150000 non-null object
# price                150000 non-null int64
# v_0                  150000 non-null float64
# v_1                  150000 non-null float64
# v_2                  150000 non-null float64
# v_3                  150000 non-null float64
# v_4                  150000 non-null float64
# v_11                 150000 non-null float64
# v_12                 150000 non-null float64
# v_14                 150000 non-null float64
# miss_info            150000 non-null int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 20.6+ MB

# %%
# 查看第二部分，包含`used_time`的数值型特征集
Train_data_2.head()
# Out:
#    SaleID  power  kilometer        v_0       v_1       v_2       v_3  \
# 0       0     60       12.5  43.357796  3.966344  0.050257  2.159744
# 1       1      0       15.0  45.305273  5.236112  0.137925  1.380657
# 2       2    163       12.5  45.978359  4.823792  1.319524 -0.998467
# 3       3    193       15.0  45.687478  4.492574 -0.050616  0.883600
# 4       4     68        5.0  44.383511  2.031433  0.572169 -1.571239
#
#         v_4      v_11      v_12      v_14  used_time  miss_info  price
# 0  1.143786  2.804097 -2.420821  0.914762     4385.0          0   1850
# 1 -1.422165  2.096338 -1.030483  0.245522     4757.0          1   3600
# 2 -0.996911  1.803559  1.565330 -0.229963     4382.0          0   6222
# 3 -2.228079  1.285940 -0.501868 -0.478699     7125.0          0   2400
# 4  2.246088  0.910783  0.931110  1.923482     1531.0          0   5200

# %%
# 查看第三部分，不含`used_time`的数值型特征集
Train_data_3.head()
# Out:
#     SaleID  power  kilometer        v_0       v_1        v_2       v_3  \
# 14      14      0       15.0  37.477726  4.439788  17.089898  2.969183
# 20      20     54       15.0  41.906646  2.069275  -0.678881  1.825039
# 22      22     75       15.0  41.346476 -3.214313  -1.102793  3.629930
# 42      42     90       15.0  44.693776  2.017017  -1.479142  2.039647
# 51      51    109       15.0  41.996992 -3.092623  -2.780618  2.706164
#
#          v_4       v_11      v_12      v_14  miss_info  price
# 14  0.301389  18.192443  5.145351  0.645098          3   6900
# 20 -0.039355   2.081788 -2.930227  0.826872          0    990
# 22  0.736763   0.346678 -3.941949 -0.157513          1    350
# 42 -0.720858   0.107458 -2.330682 -0.022019          1   1600
# 51  0.980752  -1.360968 -4.125563 -0.208094          0    350

# %% [markdown]
# ## 模型训练与评估

# %% [markdown]
# ### 利用xgb进行五折交叉验证查看模型参数的效果

# %%
## xgb-Model
xgr = xgb.XGBRegressor(n_estimators=120, learning_rate=0.1, gamma=0, subsample=0.8,\
        colsample_bytree=0.9, max_depth=7) #,objective ='reg:squarederror'

scores_train = []
scores = []


X_data = Train_data_2.drop(['SaleID', 'price'], axis=1)
Y_data = Train_data_2['price']

## 5折交叉验证方式
sk=StratifiedKFold(n_splits=5,shuffle=True,random_state=0)
for train_ind,val_ind in sk.split(X_data,Y_data):
    
    train_x=X_data.iloc[train_ind].values
    train_y=Y_data.iloc[train_ind]
    val_x=X_data.iloc[val_ind].values
    val_y=Y_data.iloc[val_ind]
    
    xgr.fit(train_x,train_y)
    pred_train_xgb=xgr.predict(train_x)
    pred_xgb=xgr.predict(val_x)
    
    score_train = mean_absolute_error(train_y,pred_train_xgb)
    scores_train.append(score_train)
    score = mean_absolute_error(val_y,pred_xgb)
    scores.append(score)

print('Train mae:',np.mean(score_train))
print('Val mae',np.mean(scores))
# Out:
# c:\users\xyao\envs\learnpy\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:06:45] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:07:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:07:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:08:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:08:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Train mae: 582.517264794879
# Val mae 674.6033826996667

# %%
Train_data
# Out:
#         SaleID  brand  bodyType  fuelType  gearbox  power  kilometer  \
# 0            0      6       1.0       0.0      0.0     60       12.5
# 1            1      1       2.0       0.0      0.0      0       15.0
# 2            2     15       1.0       0.0      0.0    163       12.5
# 3            3     10       0.0       0.0      1.0    193       15.0
# 4            4      5       1.0       0.0      0.0     68        5.0
# ...        ...    ...       ...       ...      ...    ...        ...
# 149995  149995     10       4.0       0.0      1.0    163       15.0
# 149996  149996     11       0.0       0.0      0.0    125       10.0
# 149997  149997     11       1.0       1.0      0.0     90        6.0
# 149998  149998     10       3.0       1.0      0.0    156       15.0
# 149999  149999     28       6.0       0.0      1.0    193       12.5
#
#         notRepairedDamage  price        v_0       v_1       v_2       v_3  \
# 0                     0.0   1850  43.357796  3.966344  0.050257  2.159744
# 1                     NaN   3600  45.305273  5.236112  0.137925  1.380657
# 2                     0.0   6222  45.978359  4.823792  1.319524 -0.998467
# 3                     0.0   2400  45.687478  4.492574 -0.050616  0.883600
# 4                     0.0   5200  44.383511  2.031433  0.572169 -1.571239
# ...                   ...    ...        ...       ...       ...       ...
# 149995                0.0   5900  45.316543 -3.139095 -1.269707 -0.736609
# 149996                0.0   9500  45.972058 -3.143764 -0.023523 -2.366699
# 149997                0.0   7500  44.733481 -3.105721  0.595454 -2.279091
# 149998                0.0   4999  45.658634 -3.204785 -0.441680 -1.179812
# 149999                0.0   4700  45.536383 -3.200326 -1.612893 -0.067144
#
#              v_4      v_11      v_12      v_14  miss_info  used_time
# 0       1.143786  2.804097 -2.420821  0.914762          0     4385.0
# 1      -1.422165  2.096338 -1.030483  0.245522          1     4757.0
# 2      -0.996911  1.803559  1.565330 -0.229963          0     4382.0
# 3      -2.228079  1.285940 -0.501868 -0.478699          0     7125.0
# 4       2.246088  0.910783  0.931110  1.923482          0     1531.0
# ...          ...       ...       ...       ...        ...        ...
# 149995 -1.505820 -2.983973  0.589167 -0.302592          0     5772.0
# 149996  0.698012 -2.774615  2.553994 -0.272160          0     2322.0
# 149997  1.423661 -1.630677  2.290197  0.414931          0     2003.0
# 149998  0.620680 -2.633719  1.414937 -1.659014          0     3673.0
# 149999 -1.396166 -3.179913  0.031724 -0.342674          0     6239.0
#
# [150000 rows x 19 columns]

# %% [markdown]
# 使用**网格搜索**和**交叉验证**进行超参数调整。（当然也可以尝试其他方法，如随机搜索）
#
# * 我们定义一系列选项，然后评估我们指定的每一个组合。
# * 这与随机搜索形成对比，随机搜索随机选择要尝试的组合。
#
# 通常，当我们对最佳模型超参数的知识有限时，随机搜索会更好，**我们可以使用随机搜索缩小选项范围，然后使用更有限的选项范围进行网格搜索**。
#
# **交叉验证**是用于评估超参数性能的方法：我们使用K-Fold交叉验证，而不是将训练设置拆分为单独的训练和验证集，以减少我们可以使用的训练数据量。
#
# * 这意味着将训练数据划分为K个折叠，然后进行迭代过程，我们首先在K-1个折叠上进行训练，然后评估第K个折叠的性能。
#    * 我们重复这个过程K次，所以最终我们将测试训练数据中的每个例子，关键是每次迭代我们都在测试我们之前没有训练过的数据。
#
# * 在K-Fold交叉验证结束时，我们将每个K次迭代的平均误差作为最终性能度量，然后立即在所有训练数据上训练模型。
#
# * 我们记录的性能用于比较超参数的不同组合。

# %% [markdown]
# A picture of k-fold cross validation using k = 10 is shown below:
#
# ![image.png](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1586013602923&di=49deb291884b635a027d0d87bac948d7&imgtype=0&src=http%3A%2F%2F5b0988e595225.cdn.sohucs.com%2Fimages%2F20181128%2F63366292825f43f08663c2d9650db413.jpeg)
#
# 在这里，我们将使用**交叉验证实现网格搜索**，以选择梯度增强回归量的最佳超参数。我们首先定义一个网格，然后执行以下迭代过程：
#
# * 从网格中随机抽样一组超参数，使用10折交叉验证评估超参数，
# * 然后选择具有最佳性能的超参数。
#
# 当然，我们实际上并没有自己做这个迭代，我们让Scikit-Learn和`GridSearchCV`为我们完成这个过程！

# %% [markdown]
# 我们选择了几个不同的超参数来调整梯度增强回归量。 这些都将以不同的方式影响模型，这些方法很难提前确定，找到特定问题的最佳组合的唯一方法是测试它们！ 要了解超参数，可以查看[Scikit-Learn](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html#sklearn.ensemble.GradientBoostingRegressor)文档

# %% [markdown]
# 在下面的代码中，我们创建了随机搜索对象，可以传递以下参数：
#
# * `estimator`: 模型
# * `param_distributions`: 我们定义的参数的分布
# * `cv` ：用于k-fold交叉验证的folds 数量
# * `n_iter`: 不同的参数组合的数量
# * `scoring`: 评估候选参数时使用的指标
# * `n_jobs`: 核的数量（-1 时全部使用）
# * `verbose`: 显示信息的数量
# * `return_train_score`: 每一个cross-validation fold 返回的分数
#
# 网格搜索对象的训练方式与任何其他scikit-learn模型相同。训练之后，我们可以比较所有不同的超参数组合，找到效果最好的组合。

# %%
Train_data_cat = Train_data.copy()
Train_data_cat.replace(np.nan, 'missing', inplace=True)
X_data = Train_data_cat.drop(['SaleID', 'used_time', 'price'], axis=1)
Y_data = Train_data_cat['price']

categorical_features = np.where(X_data.dtypes == 'object')[0]
for i in categorical_features:
    X_data.iloc[:, i] = X_data.iloc[:, i].astype('str')

# 使用网格搜索进行超参数调整
estimator = catboost.CatBoostRegressor(learning_rate=0.1, n_estimators=350, l2_leaf_reg=0,subsample=0.8, loss_function='MAE')
param_grid = {
    'depth': [7, 10, 12],
}

kflod = StratifiedKFold(n_splits=10, shuffle = True, random_state=42)


#scoring指定损失函数类型，n_jobs指定全部cpu跑，cv指定交叉验证
grid_search = GridSearchCV(estimator, param_grid, scoring = 'neg_mean_absolute_error',n_jobs = -1,cv = kflod)


grid_result = grid_search.fit(X_data, Y_data, cat_features=categorical_features, use_best_model=True) #运行网格搜索
print("Best: %f using %s" % (grid_result.best_score_, grid_search.best_params_))
# Out:
# c:\users\xyao\envs\learnpy\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# 0:	learn: 4111.6455396	total: 375ms	remaining: 2m 10s
# 1:	learn: 3780.7131169	total: 759ms	remaining: 2m 12s
# 2:	learn: 3482.5188121	total: 1.11s	remaining: 2m 8s
# 3:	learn: 3226.3144854	total: 1.45s	remaining: 2m 5s
# 4:	learn: 3004.8143971	total: 1.81s	remaining: 2m 4s
# 5:	learn: 2797.5545776	total: 2.18s	remaining: 2m 4s
# 6:	learn: 2622.0192160	total: 2.56s	remaining: 2m 5s
# 7:	learn: 2440.4314222	total: 2.93s	remaining: 2m 5s
# 8:	learn: 2274.4433205	total: 3.3s	remaining: 2m 5s
# 9:	learn: 2125.7553769	total: 3.65s	remaining: 2m 4s
# 10:	learn: 1995.7267340	total: 4.03s	remaining: 2m 4s
# 11:	learn: 1872.7470466	total: 4.46s	remaining: 2m 5s
# 12:	learn: 1769.2055886	total: 4.84s	remaining: 2m 5s
# 13:	learn: 1671.3331445	total: 5.23s	remaining: 2m 5s
# 14:	learn: 1587.3665891	total: 5.6s	remaining: 2m 5s
# 15:	learn: 1516.5896987	total: 5.96s	remaining: 2m 4s
# 16:	learn: 1447.2003460	total: 6.34s	remaining: 2m 4s
# 17:	learn: 1402.1101829	total: 6.72s	remaining: 2m 3s
# 18:	learn: 1348.6912605	total: 7.1s	remaining: 2m 3s
# 19:	learn: 1312.0718817	total: 7.42s	remaining: 2m 2s
# 20:	learn: 1269.3288661	total: 7.78s	remaining: 2m 1s
# 21:	learn: 1226.6417331	total: 8.14s	remaining: 2m 1s
# 22:	learn: 1195.8906965	total: 8.49s	remaining: 2m
# 23:	learn: 1164.1432124	total: 8.82s	remaining: 1m 59s
# 24:	learn: 1132.4224165	total: 9.17s	remaining: 1m 59s
# 25:	learn: 1099.7436295	total: 9.5s	remaining: 1m 58s
# 26:	learn: 1072.7615031	total: 9.84s	remaining: 1m 57s
# 27:	learn: 1048.6164084	total: 10.2s	remaining: 1m 57s
# 28:	learn: 1029.6673025	total: 10.6s	remaining: 1m 57s
# 29:	learn: 1009.4506677	total: 10.9s	remaining: 1m 56s
# 30:	learn: 996.3072822	total: 11.3s	remaining: 1m 56s
# 31:	learn: 978.8474286	total: 11.7s	remaining: 1m 55s
# 32:	learn: 966.0085315	total: 12s	remaining: 1m 55s
# 33:	learn: 952.8708287	total: 12.3s	remaining: 1m 54s
# 34:	learn: 941.1263097	total: 12.7s	remaining: 1m 54s
# 35:	learn: 935.4272121	total: 13s	remaining: 1m 53s
# 36:	learn: 923.5410644	total: 13.4s	remaining: 1m 53s
# 37:	learn: 914.1334577	total: 13.7s	remaining: 1m 52s
# 38:	learn: 905.9428287	total: 14.1s	remaining: 1m 52s
# 39:	learn: 896.0569032	total: 14.4s	remaining: 1m 51s
# 40:	learn: 888.0282834	total: 14.8s	remaining: 1m 51s
# 41:	learn: 881.4997236	total: 15.1s	remaining: 1m 50s
# 42:	learn: 874.6473698	total: 15.5s	remaining: 1m 50s
# 43:	learn: 866.9602314	total: 15.9s	remaining: 1m 50s
# 44:	learn: 862.8482069	total: 16.2s	remaining: 1m 50s
# 45:	learn: 857.5017853	total: 16.6s	remaining: 1m 49s
# 46:	learn: 851.6197532	total: 16.9s	remaining: 1m 49s
# 47:	learn: 848.5320453	total: 17.3s	remaining: 1m 48s
# 48:	learn: 841.1156445	total: 17.6s	remaining: 1m 48s
# 49:	learn: 835.4803586	total: 17.9s	remaining: 1m 47s
# 50:	learn: 831.5680035	total: 18.3s	remaining: 1m 47s
# 51:	learn: 827.5298547	total: 18.6s	remaining: 1m 46s
# 52:	learn: 824.6505576	total: 19s	remaining: 1m 46s
# 53:	learn: 821.5973995	total: 19.3s	remaining: 1m 45s
# 54:	learn: 818.8073118	total: 19.6s	remaining: 1m 45s
# 55:	learn: 816.5384034	total: 20s	remaining: 1m 44s
# 56:	learn: 814.3755863	total: 20.4s	remaining: 1m 44s
# 57:	learn: 807.5080721	total: 20.7s	remaining: 1m 44s
# 58:	learn: 804.2523212	total: 21.1s	remaining: 1m 43s
# 59:	learn: 801.3940763	total: 21.4s	remaining: 1m 43s
# 60:	learn: 799.0044181	total: 21.8s	remaining: 1m 43s
# 61:	learn: 795.7277983	total: 22.1s	remaining: 1m 42s
# 62:	learn: 794.3768866	total: 22.4s	remaining: 1m 42s
# 63:	learn: 792.3025277	total: 22.8s	remaining: 1m 41s
# 64:	learn: 789.0629424	total: 23.1s	remaining: 1m 41s
# 65:	learn: 786.1631503	total: 23.5s	remaining: 1m 41s
# 66:	learn: 782.8432876	total: 23.8s	remaining: 1m 40s
# 67:	learn: 777.0196541	total: 24.2s	remaining: 1m 40s
# 68:	learn: 774.7254151	total: 24.6s	remaining: 1m 39s
# 69:	learn: 773.3534321	total: 24.9s	remaining: 1m 39s
# 70:	learn: 772.7606629	total: 25.2s	remaining: 1m 39s
# 71:	learn: 770.7699455	total: 25.6s	remaining: 1m 38s
# 72:	learn: 769.2959411	total: 25.9s	remaining: 1m 38s
# 73:	learn: 764.6724475	total: 26.3s	remaining: 1m 37s
# 74:	learn: 762.7466107	total: 26.6s	remaining: 1m 37s
# 75:	learn: 760.3145546	total: 27s	remaining: 1m 37s
# 76:	learn: 755.2227399	total: 27.3s	remaining: 1m 36s
# 77:	learn: 751.3475810	total: 27.7s	remaining: 1m 36s
# 78:	learn: 749.6011643	total: 28s	remaining: 1m 36s
# 79:	learn: 744.6790015	total: 28.4s	remaining: 1m 35s
# 80:	learn: 740.6343760	total: 28.7s	remaining: 1m 35s
# 81:	learn: 738.6888479	total: 29.1s	remaining: 1m 35s
# 82:	learn: 737.1679029	total: 29.5s	remaining: 1m 34s
# 83:	learn: 734.8555348	total: 29.8s	remaining: 1m 34s
# 84:	learn: 731.6977483	total: 30.1s	remaining: 1m 33s
# 85:	learn: 727.9257266	total: 30.5s	remaining: 1m 33s
# 86:	learn: 724.8548501	total: 30.8s	remaining: 1m 33s
# 87:	learn: 723.4334098	total: 31.2s	remaining: 1m 32s
# 88:	learn: 719.2866672	total: 31.5s	remaining: 1m 32s
# 89:	learn: 718.0220955	total: 31.9s	remaining: 1m 32s
# 90:	learn: 716.6585136	total: 32.2s	remaining: 1m 31s
# 91:	learn: 715.5110791	total: 32.5s	remaining: 1m 31s
# 92:	learn: 712.4576355	total: 32.9s	remaining: 1m 30s
# 93:	learn: 710.0267978	total: 33.2s	remaining: 1m 30s
# 94:	learn: 708.2183835	total: 33.5s	remaining: 1m 29s
# 95:	learn: 705.0280250	total: 33.9s	remaining: 1m 29s
# 96:	learn: 703.5637573	total: 34.2s	remaining: 1m 29s
# 97:	learn: 701.1058390	total: 34.6s	remaining: 1m 28s
# 98:	learn: 699.7906701	total: 34.9s	remaining: 1m 28s
# 99:	learn: 697.5141908	total: 35.3s	remaining: 1m 28s
# 100:	learn: 696.3562286	total: 35.6s	remaining: 1m 27s
# 101:	learn: 693.4963967	total: 36s	remaining: 1m 27s
# 102:	learn: 692.7248409	total: 36.3s	remaining: 1m 27s
# 103:	learn: 691.7583641	total: 36.7s	remaining: 1m 26s
# 104:	learn: 690.8290418	total: 37s	remaining: 1m 26s
# 105:	learn: 687.9335926	total: 37.3s	remaining: 1m 25s
# 106:	learn: 686.3600797	total: 37.6s	remaining: 1m 25s
# 107:	learn: 683.8716403	total: 38s	remaining: 1m 25s
# 108:	learn: 682.9632904	total: 38.3s	remaining: 1m 24s
# 109:	learn: 679.5740248	total: 38.7s	remaining: 1m 24s
# 110:	learn: 678.7046416	total: 39s	remaining: 1m 24s
# 111:	learn: 677.6900306	total: 39.4s	remaining: 1m 23s
# 112:	learn: 677.1280142	total: 39.7s	remaining: 1m 23s
# 113:	learn: 675.7177432	total: 40.1s	remaining: 1m 23s
# 114:	learn: 675.0152333	total: 40.4s	remaining: 1m 22s
# 115:	learn: 673.8196701	total: 40.8s	remaining: 1m 22s
# 116:	learn: 673.2082725	total: 41.1s	remaining: 1m 21s
# 117:	learn: 671.5173527	total: 41.5s	remaining: 1m 21s
# 118:	learn: 670.8904791	total: 41.8s	remaining: 1m 21s
# 119:	learn: 668.2227109	total: 42.2s	remaining: 1m 20s
# 120:	learn: 666.3544749	total: 42.5s	remaining: 1m 20s
# 121:	learn: 665.4394431	total: 42.9s	remaining: 1m 20s
# 122:	learn: 664.1879074	total: 43.2s	remaining: 1m 19s
# 123:	learn: 663.3648922	total: 43.6s	remaining: 1m 19s
# 124:	learn: 662.6257369	total: 44s	remaining: 1m 19s
# 125:	learn: 661.0534487	total: 44.3s	remaining: 1m 18s
# 126:	learn: 658.3880956	total: 44.7s	remaining: 1m 18s
# 127:	learn: 656.8218903	total: 45s	remaining: 1m 18s
# 128:	learn: 655.5995035	total: 45.3s	remaining: 1m 17s
# 129:	learn: 654.1370455	total: 45.7s	remaining: 1m 17s
# 130:	learn: 650.9983788	total: 46s	remaining: 1m 16s
# 131:	learn: 650.3979109	total: 46.4s	remaining: 1m 16s
# 132:	learn: 647.9572664	total: 46.7s	remaining: 1m 16s
# 133:	learn: 647.0956380	total: 47s	remaining: 1m 15s
# 134:	learn: 645.7409926	total: 47.4s	remaining: 1m 15s
# 135:	learn: 643.7756359	total: 47.7s	remaining: 1m 15s
# 136:	learn: 642.8907362	total: 48s	remaining: 1m 14s
# 137:	learn: 641.9182623	total: 48.4s	remaining: 1m 14s
# 138:	learn: 641.3092180	total: 48.7s	remaining: 1m 13s
# 139:	learn: 640.7264374	total: 49s	remaining: 1m 13s
# 140:	learn: 640.0567406	total: 49.4s	remaining: 1m 13s
# 141:	learn: 637.9333855	total: 49.7s	remaining: 1m 12s
# 142:	learn: 637.2115481	total: 50s	remaining: 1m 12s
# 143:	learn: 636.3267719	total: 50.4s	remaining: 1m 12s
# 144:	learn: 634.8868143	total: 50.7s	remaining: 1m 11s
# 145:	learn: 634.5969508	total: 51s	remaining: 1m 11s
# 146:	learn: 633.8126668	total: 51.4s	remaining: 1m 10s
# 147:	learn: 633.4052703	total: 51.7s	remaining: 1m 10s
# 148:	learn: 631.7673811	total: 52s	remaining: 1m 10s
# 149:	learn: 630.2276032	total: 52.4s	remaining: 1m 9s
# 150:	learn: 628.5090498	total: 52.7s	remaining: 1m 9s
# 151:	learn: 626.4435807	total: 53s	remaining: 1m 9s
# 152:	learn: 624.5090577	total: 53.3s	remaining: 1m 8s
# 153:	learn: 623.2054201	total: 53.7s	remaining: 1m 8s
# 154:	learn: 622.6778645	total: 54s	remaining: 1m 7s
# 155:	learn: 621.4689064	total: 54.4s	remaining: 1m 7s
# 156:	learn: 618.8699851	total: 54.7s	remaining: 1m 7s
# 157:	learn: 618.3249644	total: 55s	remaining: 1m 6s
# 158:	learn: 617.6954808	total: 55.4s	remaining: 1m 6s
# 159:	learn: 615.7747370	total: 55.7s	remaining: 1m 6s
# 160:	learn: 615.5898361	total: 56.1s	remaining: 1m 5s
# 161:	learn: 614.6501594	total: 56.4s	remaining: 1m 5s
# 162:	learn: 613.4348473	total: 56.7s	remaining: 1m 5s
# 163:	learn: 612.8117260	total: 57.1s	remaining: 1m 4s
# 164:	learn: 612.0420597	total: 57.4s	remaining: 1m 4s
# 165:	learn: 611.3684547	total: 57.7s	remaining: 1m 3s
# 166:	learn: 609.6504787	total: 58.1s	remaining: 1m 3s
# 167:	learn: 609.2451488	total: 58.4s	remaining: 1m 3s
# 168:	learn: 608.8213297	total: 58.7s	remaining: 1m 2s
# 169:	learn: 607.5274321	total: 59s	remaining: 1m 2s
# 170:	learn: 605.9788560	total: 59.3s	remaining: 1m 2s
# 171:	learn: 604.8594406	total: 59.6s	remaining: 1m 1s
# 172:	learn: 603.8402110	total: 59.9s	remaining: 1m 1s
# 173:	learn: 603.4739835	total: 1m	remaining: 1m
# 174:	learn: 603.0690354	total: 1m	remaining: 1m
# 175:	learn: 601.3871044	total: 1m	remaining: 1m
# 176:	learn: 599.9243135	total: 1m 1s	remaining: 59.7s
# 177:	learn: 599.5246068	total: 1m 1s	remaining: 59.3s
# 178:	learn: 598.6556567	total: 1m 1s	remaining: 58.9s
# 179:	learn: 597.7458118	total: 1m 1s	remaining: 58.5s
# 180:	learn: 597.1120825	total: 1m 2s	remaining: 58.1s
# 181:	learn: 595.7601674	total: 1m 2s	remaining: 57.8s
# 182:	learn: 595.5430815	total: 1m 2s	remaining: 57.4s
# 183:	learn: 594.9085056	total: 1m 3s	remaining: 57s
# 184:	learn: 593.8382489	total: 1m 3s	remaining: 56.6s
# 185:	learn: 593.5382650	total: 1m 3s	remaining: 56.2s
# 186:	learn: 593.3391442	total: 1m 4s	remaining: 55.8s
# 187:	learn: 592.7839066	total: 1m 4s	remaining: 55.5s
# 188:	learn: 592.5651138	total: 1m 4s	remaining: 55.1s
# 189:	learn: 591.5804920	total: 1m 4s	remaining: 54.7s
# 190:	learn: 590.4041122	total: 1m 5s	remaining: 54.3s
# 191:	learn: 590.0334251	total: 1m 5s	remaining: 53.9s
# 192:	learn: 588.2639757	total: 1m 5s	remaining: 53.6s
# 193:	learn: 588.0373616	total: 1m 6s	remaining: 53.2s
# 194:	learn: 586.7081410	total: 1m 6s	remaining: 52.8s
# 195:	learn: 586.0029665	total: 1m 6s	remaining: 52.4s
# 196:	learn: 585.9065095	total: 1m 6s	remaining: 52s
# 197:	learn: 584.3778791	total: 1m 7s	remaining: 51.7s
# 198:	learn: 583.3568692	total: 1m 7s	remaining: 51.3s
# 199:	learn: 582.5695012	total: 1m 7s	remaining: 50.9s
# 200:	learn: 582.1379714	total: 1m 8s	remaining: 50.6s
# 201:	learn: 581.4501774	total: 1m 8s	remaining: 50.2s
# 202:	learn: 580.9166646	total: 1m 8s	remaining: 49.8s
# 203:	learn: 580.1885195	total: 1m 9s	remaining: 49.5s
# 204:	learn: 579.5587472	total: 1m 9s	remaining: 49.1s
# 205:	learn: 578.9141993	total: 1m 9s	remaining: 48.8s
# 206:	learn: 578.5271495	total: 1m 10s	remaining: 48.4s
# 207:	learn: 578.2259853	total: 1m 10s	remaining: 48s
# 208:	learn: 577.8386691	total: 1m 10s	remaining: 47.7s
# 209:	learn: 576.4538578	total: 1m 10s	remaining: 47.3s
# 210:	learn: 575.4959867	total: 1m 11s	remaining: 47s
# 211:	learn: 575.2088103	total: 1m 11s	remaining: 46.7s
# 212:	learn: 575.0606793	total: 1m 11s	remaining: 46.3s
# 213:	learn: 574.5024970	total: 1m 12s	remaining: 45.9s
# 214:	learn: 573.6295418	total: 1m 12s	remaining: 45.6s
# 215:	learn: 572.8016777	total: 1m 12s	remaining: 45.2s
# 216:	learn: 571.5932634	total: 1m 13s	remaining: 44.9s
# 217:	learn: 571.1980521	total: 1m 13s	remaining: 44.5s
# 218:	learn: 570.8320030	total: 1m 13s	remaining: 44.1s
# 219:	learn: 570.3335888	total: 1m 14s	remaining: 43.8s
# 220:	learn: 569.5111740	total: 1m 14s	remaining: 43.4s
# 221:	learn: 567.3206892	total: 1m 14s	remaining: 43.1s
# 222:	learn: 567.1139389	total: 1m 15s	remaining: 42.7s
# 223:	learn: 566.6763411	total: 1m 15s	remaining: 42.4s
# 224:	learn: 566.2391724	total: 1m 15s	remaining: 42s
# 225:	learn: 565.5314403	total: 1m 15s	remaining: 41.7s
# 226:	learn: 565.1223693	total: 1m 16s	remaining: 41.3s
# 227:	learn: 564.4044149	total: 1m 16s	remaining: 41s
# 228:	learn: 564.1497328	total: 1m 16s	remaining: 40.6s
# 229:	learn: 563.8464167	total: 1m 17s	remaining: 40.3s
# 230:	learn: 562.8892722	total: 1m 17s	remaining: 39.9s
# 231:	learn: 562.2619036	total: 1m 17s	remaining: 39.6s
# 232:	learn: 560.5129314	total: 1m 18s	remaining: 39.2s
# 233:	learn: 559.4030438	total: 1m 18s	remaining: 38.9s
# 234:	learn: 559.0972396	total: 1m 18s	remaining: 38.5s
# 235:	learn: 557.8586875	total: 1m 18s	remaining: 38.1s
# 236:	learn: 556.9211060	total: 1m 19s	remaining: 37.8s
# 237:	learn: 556.1795461	total: 1m 19s	remaining: 37.4s
# 238:	learn: 555.9451241	total: 1m 19s	remaining: 37.1s
# 239:	learn: 555.1406450	total: 1m 20s	remaining: 36.7s
# 240:	learn: 554.4100411	total: 1m 20s	remaining: 36.4s
# 241:	learn: 553.9601434	total: 1m 20s	remaining: 36s
# 242:	learn: 553.6477106	total: 1m 21s	remaining: 35.7s
# 243:	learn: 553.2755972	total: 1m 21s	remaining: 35.3s
# 244:	learn: 553.1477460	total: 1m 21s	remaining: 35s
# 245:	learn: 552.4315773	total: 1m 21s	remaining: 34.6s
# 246:	learn: 551.5183906	total: 1m 22s	remaining: 34.3s
# 247:	learn: 551.1910255	total: 1m 22s	remaining: 33.9s
# 248:	learn: 550.6660883	total: 1m 22s	remaining: 33.6s
# 249:	learn: 549.7878351	total: 1m 23s	remaining: 33.3s
# 250:	learn: 548.9744842	total: 1m 23s	remaining: 32.9s
# 251:	learn: 547.1374322	total: 1m 23s	remaining: 32.6s
# 252:	learn: 546.5628676	total: 1m 24s	remaining: 32.2s
# 253:	learn: 546.2244509	total: 1m 24s	remaining: 31.9s
# 254:	learn: 545.6729785	total: 1m 24s	remaining: 31.5s
# 255:	learn: 545.2915477	total: 1m 24s	remaining: 31.2s
# 256:	learn: 544.6767094	total: 1m 25s	remaining: 30.8s
# 257:	learn: 544.2275239	total: 1m 25s	remaining: 30.5s
# 258:	learn: 543.6298886	total: 1m 25s	remaining: 30.2s
# 259:	learn: 543.0578378	total: 1m 26s	remaining: 29.8s
# 260:	learn: 542.6699658	total: 1m 26s	remaining: 29.5s
# 261:	learn: 542.4965078	total: 1m 26s	remaining: 29.1s
# 262:	learn: 541.6053248	total: 1m 27s	remaining: 28.8s
# 263:	learn: 541.0717880	total: 1m 27s	remaining: 28.5s
# 264:	learn: 540.5426608	total: 1m 27s	remaining: 28.1s
# 265:	learn: 540.0883750	total: 1m 27s	remaining: 27.8s
# 266:	learn: 539.9804815	total: 1m 28s	remaining: 27.4s
# 267:	learn: 539.5899877	total: 1m 28s	remaining: 27.1s
# 268:	learn: 538.4406156	total: 1m 28s	remaining: 26.8s
# 269:	learn: 538.0558917	total: 1m 29s	remaining: 26.4s
# 270:	learn: 537.7897679	total: 1m 29s	remaining: 26.1s
# 271:	learn: 537.3710877	total: 1m 29s	remaining: 25.7s
# 272:	learn: 536.0591950	total: 1m 30s	remaining: 25.4s
# 273:	learn: 535.8130662	total: 1m 30s	remaining: 25.1s
# 274:	learn: 534.8481052	total: 1m 30s	remaining: 24.7s
# 275:	learn: 534.5769438	total: 1m 30s	remaining: 24.4s
# 276:	learn: 533.9887576	total: 1m 31s	remaining: 24s
# 277:	learn: 533.6791390	total: 1m 31s	remaining: 23.7s
# 278:	learn: 533.0359829	total: 1m 31s	remaining: 23.4s
# 279:	learn: 532.3853967	total: 1m 32s	remaining: 23s
# 280:	learn: 531.9740314	total: 1m 32s	remaining: 22.7s
# 281:	learn: 531.1101175	total: 1m 32s	remaining: 22.4s
# 282:	learn: 530.7475426	total: 1m 33s	remaining: 22s
# 283:	learn: 530.3839797	total: 1m 33s	remaining: 21.7s
# 284:	learn: 530.0412706	total: 1m 33s	remaining: 21.3s
# 285:	learn: 529.8071424	total: 1m 33s	remaining: 21s
# 286:	learn: 529.3161507	total: 1m 34s	remaining: 20.7s
# 287:	learn: 528.8887132	total: 1m 34s	remaining: 20.3s
# 288:	learn: 528.6531533	total: 1m 34s	remaining: 20s
# 289:	learn: 528.1770341	total: 1m 35s	remaining: 19.7s
# 290:	learn: 527.7425034	total: 1m 35s	remaining: 19.4s
# 291:	learn: 527.3862325	total: 1m 35s	remaining: 19s
# 292:	learn: 527.2119035	total: 1m 36s	remaining: 18.7s
# 293:	learn: 527.0493084	total: 1m 36s	remaining: 18.4s
# 294:	learn: 526.8039492	total: 1m 36s	remaining: 18s
# 295:	learn: 526.1534311	total: 1m 37s	remaining: 17.7s
# 296:	learn: 525.8883454	total: 1m 37s	remaining: 17.4s
# 297:	learn: 525.7475008	total: 1m 37s	remaining: 17.1s
# 298:	learn: 525.3453026	total: 1m 38s	remaining: 16.7s
# 299:	learn: 525.0859538	total: 1m 38s	remaining: 16.4s
# 300:	learn: 524.8605850	total: 1m 38s	remaining: 16.1s
# 301:	learn: 524.3392700	total: 1m 38s	remaining: 15.7s
# 302:	learn: 523.2314618	total: 1m 39s	remaining: 15.4s
# 303:	learn: 522.7219003	total: 1m 39s	remaining: 15.1s
# 304:	learn: 522.0546735	total: 1m 39s	remaining: 14.7s
# 305:	learn: 521.5411882	total: 1m 40s	remaining: 14.4s
# 306:	learn: 520.7998467	total: 1m 40s	remaining: 14.1s
# 307:	learn: 520.4805162	total: 1m 40s	remaining: 13.7s
# 308:	learn: 520.1494215	total: 1m 41s	remaining: 13.4s
# 309:	learn: 519.3698598	total: 1m 41s	remaining: 13.1s
# 310:	learn: 518.9550328	total: 1m 41s	remaining: 12.8s
# 311:	learn: 518.5725719	total: 1m 42s	remaining: 12.4s
# 312:	learn: 518.3877688	total: 1m 42s	remaining: 12.1s
# 313:	learn: 518.1636906	total: 1m 42s	remaining: 11.8s
# 314:	learn: 517.9855828	total: 1m 43s	remaining: 11.4s
# 315:	learn: 517.7857855	total: 1m 43s	remaining: 11.1s
# 316:	learn: 516.5934899	total: 1m 43s	remaining: 10.8s
# 317:	learn: 516.4359410	total: 1m 43s	remaining: 10.5s
# 318:	learn: 516.3484693	total: 1m 44s	remaining: 10.1s
# 319:	learn: 515.9331889	total: 1m 44s	remaining: 9.8s
# 320:	learn: 515.7256809	total: 1m 44s	remaining: 9.47s
# 321:	learn: 515.1100753	total: 1m 45s	remaining: 9.14s
# 322:	learn: 513.8211902	total: 1m 45s	remaining: 8.81s
# 323:	learn: 513.1788554	total: 1m 45s	remaining: 8.48s
# 324:	learn: 512.8324112	total: 1m 46s	remaining: 8.16s
# 325:	learn: 512.6375767	total: 1m 46s	remaining: 7.83s
# 326:	learn: 512.2164701	total: 1m 46s	remaining: 7.5s
# 327:	learn: 512.1238258	total: 1m 46s	remaining: 7.17s
# 328:	learn: 511.8071258	total: 1m 47s	remaining: 6.85s
# 329:	learn: 511.2130277	total: 1m 47s	remaining: 6.52s
# 330:	learn: 511.0326224	total: 1m 47s	remaining: 6.19s
# 331:	learn: 510.7415261	total: 1m 48s	remaining: 5.87s
# 332:	learn: 510.3748695	total: 1m 48s	remaining: 5.54s
# 333:	learn: 510.1131978	total: 1m 48s	remaining: 5.21s
# 334:	learn: 509.3706131	total: 1m 49s	remaining: 4.89s
# 335:	learn: 508.9710876	total: 1m 49s	remaining: 4.57s
# 336:	learn: 508.7827660	total: 1m 49s	remaining: 4.24s
# 337:	learn: 508.3248128	total: 1m 50s	remaining: 3.91s
# 338:	learn: 508.1328961	total: 1m 50s	remaining: 3.59s
# 339:	learn: 507.7498388	total: 1m 50s	remaining: 3.26s
# 340:	learn: 507.5767627	total: 1m 51s	remaining: 2.93s
# 341:	learn: 507.2242622	total: 1m 51s	remaining: 2.61s
# 342:	learn: 506.9798524	total: 1m 51s	remaining: 2.28s
# 343:	learn: 506.8567274	total: 1m 52s	remaining: 1.95s
# 344:	learn: 506.3708334	total: 1m 52s	remaining: 1.63s
# 345:	learn: 506.1714220	total: 1m 52s	remaining: 1.3s
# 346:	learn: 505.5678612	total: 1m 52s	remaining: 977ms
# 347:	learn: 504.6424301	total: 1m 53s	remaining: 651ms
# 348:	learn: 503.7869965	total: 1m 53s	remaining: 325ms
# 349:	learn: 503.5364477	total: 1m 53s	remaining: 0us
# Best: -654.660276 using {'depth': 12}

# %%
X_data = Train_data_2.drop(['SaleID', 'price'], axis=1)
Y_data = Train_data_2['price']

# 使用网格搜索进行超参数调整
estimator = xgb.XGBRegressor(learning_rate=0.2,gamma=0, subsample=0.8, colsample_bytree=0.9, max_depth=10)
param_grid = {
    'subsample': [0.8],
    'n_estimators': [300, 350]
}

kflod = StratifiedKFold(n_splits=10, shuffle = True, random_state=42)


#scoring指定损失函数类型，n_jobs指定全部cpu跑，cv指定交叉验证
grid_search = GridSearchCV(estimator, param_grid, scoring = 'neg_mean_absolute_error',n_jobs = -1,cv = kflod)


grid_result = grid_search.fit(X_data, Y_data) #运行网格搜索
print("Best: %f using %s" % (grid_result.best_score_, grid_search.best_params_))
# Out:
# c:\users\xyao\envs\learnpy\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [12:37:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Best: -611.329735 using {'n_estimators': 350, 'subsample': 0.8}

# %%
X_data = Train_data_3.drop(['SaleID', 'price'], axis=1)
Y_data = Train_data_3['price']

# 使用网格搜索进行超参数调整
estimator = xgb.XGBRegressor(learning_rate=0.1, gamma=0,subsample=0.8, colsample_bytree=0.9, max_depth=12)
param_grid = {
    'n_estimators': [400, 450],
}

kflod = StratifiedKFold(n_splits=10, shuffle = True, random_state=42)


#scoring指定损失函数类型，n_jobs指定全部cpu跑，cv指定交叉验证
grid_search = GridSearchCV(estimator, param_grid, scoring = 'neg_mean_absolute_error',n_jobs = -1,cv = kflod)


grid_result = grid_search.fit(X_data, Y_data) #运行网格搜索
print("Best: %f using %s" % (grid_result.best_score_, grid_search.best_params_))
# Out:
# c:\users\xyao\envs\learnpy\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [17:29:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Best: -328.781713 using {'max_depth': 12, 'n_estimators': 400}

# %%
X_data = Train_data_2.drop(['SaleID', 'price'], axis=1)
Y_data = Train_data_2['price']

# 使用网格搜索进行超参数调整
estimator = lgb.LGBMRegressor(learning_rate=0.1,gamma=0, subsample=0.8, colsample_bytree=0.9, max_depth=20)
param_grid = {
    'n_estimators': [450, 500, 550]
}

kflod = StratifiedKFold(n_splits=10, shuffle = True, random_state=42)


#scoring指定损失函数类型，n_jobs指定全部cpu跑，cv指定交叉验证
grid_search = GridSearchCV(estimator, param_grid, scoring = 'neg_mean_absolute_error',n_jobs = -1,cv = kflod)


grid_result = grid_search.fit(X_data, Y_data) #运行网格搜索
print("Best: %f using %s" % (grid_result.best_score_, grid_search.best_params_))
# Out:
# c:\users\xyao\envs\learnpy\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# Best: -628.116327 using {'n_estimators': 550}

# %%
X_data = Train_data_3.drop(['SaleID', 'price'], axis=1)
Y_data = Train_data_3['price']

# 使用网格搜索进行超参数调整
estimator = lgb.LGBMRegressor(learning_rate=0.1,gamma=0, subsample=0.8, colsample_bytree=0.9)
param_grid = {
    'max_depth': [17, 20, 22],
    'n_estimators': [600, 650]
}

kflod = StratifiedKFold(n_splits=10, shuffle = True, random_state=42)


#scoring指定损失函数类型，n_jobs指定全部cpu跑，cv指定交叉验证
grid_search = GridSearchCV(estimator, param_grid, scoring = 'neg_mean_absolute_error',n_jobs = -1,cv = kflod)


grid_result = grid_search.fit(X_data, Y_data) #运行网格搜索
print("Best: %f using %s" % (grid_result.best_score_, grid_search.best_params_))
# Out:
# c:\users\xyao\envs\learnpy\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# Best: -348.606713 using {'max_depth': 22, 'n_estimators': 650}

# %% [markdown]
# Scikit-learn使用负平均绝对误差进行评估，因为它希望度量最大化。因此，更好的分数将接近0。
#
# 我们可以将随机搜索的结果导入数据帧，并按性能对值进行排序。

# %%
# 获取所有cv结果并按测试性能排序
random_results = pd.DataFrame(grid_result.cv_results_).sort_values('mean_test_score', ascending = False)

random_results.head(10)

# %% [markdown]
# 训练误差和测试误差之间始终存在差异（训练误差始终较低）但如果存在显着差异，我们希望通过**获取更多训练数据或通过超参数调整或正则化降低模型的复杂度**来尝试减少过拟合。对于gradient boosting regressor，一些选项包括:
#
# * 减少树的数量
# * 减少每棵树的最大深度
# * 以及增加叶节点中的最小样本数。
#
# 对于任何想要进一步深入渐变增强回归量的人来说，[这是一篇很棒的文章](http://blog.kaggle.com/2017/01/23/a-kaggle-master-explains-gradient-boosting/)。目前，我们将使用具有最佳性能的模型，并接受它可能过拟合到训练集。

# %% [markdown]
# ## 训练与预测

# %% [markdown]
# ### 定义catboost、xgboost、lightgbm模型

# %%
def build_model_cat(x_train, y_train, cat_features):
    model_cat = catboost.CatBoostRegressor(learning_rate=0.1, n_estimators=350, 
                                       l2_leaf_reg=0,subsample=0.8, loss_function='MAE', depth=12)
    model_cat.fit(x_train, y_train, cat_features=cat_features, use_best_model=True)
    return model_cat


def build_model_xgb_1(x_train,y_train):
    xgb_1 = xgb.XGBRegressor(n_estimators=350,learning_rate=0.2,gamma=0, subsample=0.8, 
                             colsample_bytree=0.9, max_depth=10) #, objective ='reg:squarederror'
    xgb_1.fit(x_train, y_train)
    return xgb_1

def build_model_xgb_2(x_train,y_train):
    xgb_2 = xgb.XGBRegressor(n_estimators=400,learning_rate=0.1,gamma=0, subsample=0.8, 
                             colsample_bytree=0.9, max_depth=12) #, objective ='reg:squarederror'
    xgb_2.fit(x_train, y_train)
    return xgb_2

def build_model_lgb_1(x_train,y_train):
    lgb_1 = lgb.LGBMRegressor(n_estimators=550, learning_rate=0.1,gamma=0, subsample=0.8, 
                                  colsample_bytree=0.9, max_depth=20)
    
    lgb_1.fit(x_train, y_train)
    return lgb_1

def build_model_lgb_2(x_train,y_train):
    lgb_2 = lgb.LGBMRegressor(n_estimators=650, learning_rate=0.1,gamma=0, subsample=0.8, 
                                  colsample_bytree=0.9, max_depth=22)
    
    lgb_2.fit(x_train, y_train)
    return lgb_2

# %% [markdown]
# ### 使用Catboost模型

# %%
# 使用catoost对数据1进行训练与预测

X_train = Train_data_1.drop(['SaleID', 'price'], axis=1)
Y_train = Train_data_1['price']

X_test = Test_data_1.drop('SaleID', axis=1)
res_cat = pd.DataFrame()
res_cat['SaleID'] = Test_data_1['SaleID']

categorical_features_train = np.where(X_train.dtypes == 'object')[0]
for i in categorical_features_train:
    X_train.iloc[:, i] = X_train.iloc[:, i].astype('str')

categorical_features_test = np.where(X_test.dtypes == 'object')[0]
for i in categorical_features_test:
    X_test.iloc[:, i] = X_test.iloc[:, i].astype('str')

test_pool = catboost.Pool(X_test, cat_features=categorical_features_test)

print('Train catboost ...')
model_cat = build_model_cat(X_train, Y_train, cat_features=categorical_features)
val_cat = model_cat.predict(X_train)
MAE_cat = mean_absolute_error(Y_train, val_cat)
print('MAE with catboost:' ,MAE_cat)

print('Predict catboost ...')
res_cat['price'] = model_cat.predict(test_pool)
print('Catboost Done!')
# Out:
# Train catboost ...
# You should provide test set for use best model. use_best_model parameter has been switched to false value.
# 0:	learn: 4119.8529224	total: 328ms	remaining: 1m 54s
# 1:	learn: 3791.2374326	total: 698ms	remaining: 2m 1s
# 2:	learn: 3485.4772356	total: 1.07s	remaining: 2m 3s
# 3:	learn: 3256.2890088	total: 1.39s	remaining: 2m
# 4:	learn: 3033.8341876	total: 1.72s	remaining: 1m 58s
# 5:	learn: 2815.7639492	total: 2.07s	remaining: 1m 58s
# 6:	learn: 2634.4927667	total: 2.49s	remaining: 2m 1s
# 7:	learn: 2453.2242641	total: 2.85s	remaining: 2m 1s
# 8:	learn: 2290.5821979	total: 3.19s	remaining: 2m
# 9:	learn: 2151.2457233	total: 3.52s	remaining: 1m 59s
# 10:	learn: 2018.8429989	total: 3.85s	remaining: 1m 58s
# 11:	learn: 1904.3195954	total: 4.17s	remaining: 1m 57s
# 12:	learn: 1811.7749129	total: 4.51s	remaining: 1m 56s
# 13:	learn: 1712.0217440	total: 4.88s	remaining: 1m 57s
# 14:	learn: 1622.0318732	total: 5.24s	remaining: 1m 56s
# 15:	learn: 1543.1834913	total: 5.58s	remaining: 1m 56s
# 16:	learn: 1470.2752094	total: 5.9s	remaining: 1m 55s
# 17:	learn: 1405.2782224	total: 6.23s	remaining: 1m 54s
# 18:	learn: 1353.5854199	total: 6.56s	remaining: 1m 54s
# 19:	learn: 1308.9549209	total: 6.87s	remaining: 1m 53s
# 20:	learn: 1262.5698237	total: 7.2s	remaining: 1m 52s
# 21:	learn: 1218.0400109	total: 7.51s	remaining: 1m 52s
# 22:	learn: 1181.2794375	total: 7.83s	remaining: 1m 51s
# 23:	learn: 1145.9675647	total: 8.14s	remaining: 1m 50s
# 24:	learn: 1118.3649697	total: 8.45s	remaining: 1m 49s
# 25:	learn: 1089.7752078	total: 8.77s	remaining: 1m 49s
# 26:	learn: 1061.1820824	total: 9.09s	remaining: 1m 48s
# 27:	learn: 1037.3624614	total: 9.4s	remaining: 1m 48s
# 28:	learn: 1017.6765339	total: 9.71s	remaining: 1m 47s
# 29:	learn: 999.8661696	total: 10s	remaining: 1m 46s
# 30:	learn: 986.7688016	total: 10.4s	remaining: 1m 46s
# 31:	learn: 974.2933603	total: 10.7s	remaining: 1m 46s
# 32:	learn: 962.1364061	total: 11s	remaining: 1m 45s
# 33:	learn: 952.1218582	total: 11.3s	remaining: 1m 45s
# 34:	learn: 945.0616031	total: 11.6s	remaining: 1m 44s
# 35:	learn: 936.0789556	total: 12s	remaining: 1m 44s
# 36:	learn: 925.7202012	total: 12.3s	remaining: 1m 44s
# 37:	learn: 915.2485050	total: 12.6s	remaining: 1m 43s
# 38:	learn: 905.0834174	total: 12.9s	remaining: 1m 43s
# 39:	learn: 897.3830423	total: 13.3s	remaining: 1m 42s
# 40:	learn: 889.1023462	total: 13.6s	remaining: 1m 42s
# 41:	learn: 883.8191201	total: 13.9s	remaining: 1m 41s
# 42:	learn: 878.9308206	total: 14.2s	remaining: 1m 41s
# 43:	learn: 872.2291044	total: 14.5s	remaining: 1m 41s
# 44:	learn: 868.2107957	total: 14.8s	remaining: 1m 40s
# 45:	learn: 862.1411789	total: 15.2s	remaining: 1m 40s
# 46:	learn: 856.0590438	total: 15.5s	remaining: 1m 39s
# 47:	learn: 852.8461372	total: 15.8s	remaining: 1m 39s
# 48:	learn: 847.4531052	total: 16.1s	remaining: 1m 39s
# 49:	learn: 842.2124514	total: 16.4s	remaining: 1m 38s
# 50:	learn: 836.9728422	total: 16.8s	remaining: 1m 38s
# 51:	learn: 833.2400418	total: 17.1s	remaining: 1m 37s
# 52:	learn: 829.6409524	total: 17.4s	remaining: 1m 37s
# 53:	learn: 825.2434283	total: 17.7s	remaining: 1m 37s
# 54:	learn: 818.8399952	total: 18s	remaining: 1m 36s
# 55:	learn: 815.1094679	total: 18.4s	remaining: 1m 36s
# 56:	learn: 809.8528524	total: 18.7s	remaining: 1m 35s
# 57:	learn: 806.7128361	total: 19s	remaining: 1m 35s
# 58:	learn: 804.4958582	total: 19.3s	remaining: 1m 35s
# 59:	learn: 802.5296885	total: 19.6s	remaining: 1m 34s
# 60:	learn: 798.4485019	total: 20s	remaining: 1m 34s
# 61:	learn: 795.9773180	total: 20.3s	remaining: 1m 34s
# 62:	learn: 794.3708576	total: 20.6s	remaining: 1m 33s
# 63:	learn: 791.2398497	total: 20.9s	remaining: 1m 33s
# 64:	learn: 787.0478089	total: 21.2s	remaining: 1m 33s
# 65:	learn: 782.6215853	total: 21.6s	remaining: 1m 32s
# 66:	learn: 780.0072824	total: 21.9s	remaining: 1m 32s
# 67:	learn: 775.7406012	total: 22.2s	remaining: 1m 32s
# 68:	learn: 771.4666516	total: 22.5s	remaining: 1m 31s
# 69:	learn: 769.9376407	total: 22.8s	remaining: 1m 31s
# 70:	learn: 767.9623332	total: 23.2s	remaining: 1m 31s
# 71:	learn: 765.8704367	total: 23.5s	remaining: 1m 30s
# 72:	learn: 762.9791364	total: 23.9s	remaining: 1m 30s
# 73:	learn: 758.0648972	total: 24.2s	remaining: 1m 30s
# 74:	learn: 755.7417671	total: 24.6s	remaining: 1m 30s
# 75:	learn: 749.5011036	total: 24.9s	remaining: 1m 29s
# 76:	learn: 746.3266742	total: 25.2s	remaining: 1m 29s
# 77:	learn: 744.5451157	total: 25.6s	remaining: 1m 29s
# 78:	learn: 739.5193874	total: 25.9s	remaining: 1m 28s
# 79:	learn: 738.1134641	total: 26.3s	remaining: 1m 28s
# 80:	learn: 734.2506395	total: 26.6s	remaining: 1m 28s
# 81:	learn: 731.7450938	total: 26.9s	remaining: 1m 27s
# 82:	learn: 729.5417394	total: 27.2s	remaining: 1m 27s
# 83:	learn: 727.5797877	total: 27.6s	remaining: 1m 27s
# 84:	learn: 725.3700027	total: 27.9s	remaining: 1m 26s
# 85:	learn: 723.3577372	total: 28.2s	remaining: 1m 26s
# 86:	learn: 720.3515201	total: 28.5s	remaining: 1m 26s
# 87:	learn: 718.4501217	total: 28.8s	remaining: 1m 25s
# 88:	learn: 717.6509600	total: 29.1s	remaining: 1m 25s
# 89:	learn: 716.6825386	total: 29.4s	remaining: 1m 25s
# 90:	learn: 714.9053169	total: 29.8s	remaining: 1m 24s
# 91:	learn: 712.9395008	total: 30.1s	remaining: 1m 24s
# 92:	learn: 710.7628696	total: 30.4s	remaining: 1m 23s
# 93:	learn: 708.6605569	total: 30.7s	remaining: 1m 23s
# 94:	learn: 703.8218472	total: 31s	remaining: 1m 23s
# 95:	learn: 702.4742214	total: 31.3s	remaining: 1m 22s
# 96:	learn: 698.1341361	total: 31.7s	remaining: 1m 22s
# 97:	learn: 696.7398653	total: 32s	remaining: 1m 22s
# 98:	learn: 695.6894600	total: 32.4s	remaining: 1m 22s
# 99:	learn: 694.8708602	total: 32.7s	remaining: 1m 21s
# 100:	learn: 693.1460552	total: 33s	remaining: 1m 21s
# 101:	learn: 691.9158878	total: 33.3s	remaining: 1m 21s
# 102:	learn: 691.1515470	total: 33.7s	remaining: 1m 20s
# 103:	learn: 688.8128177	total: 34.1s	remaining: 1m 20s
# 104:	learn: 688.4578974	total: 34.4s	remaining: 1m 20s
# 105:	learn: 687.5139581	total: 34.8s	remaining: 1m 20s
# 106:	learn: 685.9365923	total: 35.1s	remaining: 1m 19s
# 107:	learn: 683.2248852	total: 35.4s	remaining: 1m 19s
# 108:	learn: 680.4980186	total: 35.7s	remaining: 1m 18s
# 109:	learn: 679.1080046	total: 36.1s	remaining: 1m 18s
# 110:	learn: 678.1642599	total: 36.4s	remaining: 1m 18s
# 111:	learn: 675.5061294	total: 36.7s	remaining: 1m 18s
# 112:	learn: 673.7022517	total: 37s	remaining: 1m 17s
# 113:	learn: 670.8642398	total: 37.4s	remaining: 1m 17s
# 114:	learn: 668.6092507	total: 37.7s	remaining: 1m 16s
# 115:	learn: 666.8486482	total: 38s	remaining: 1m 16s
# 116:	learn: 664.0574155	total: 38.3s	remaining: 1m 16s
# 117:	learn: 661.5751745	total: 38.6s	remaining: 1m 15s
# 118:	learn: 660.5377370	total: 38.9s	remaining: 1m 15s
# 119:	learn: 658.8729932	total: 39.3s	remaining: 1m 15s
# 120:	learn: 657.4245922	total: 39.6s	remaining: 1m 14s
# 121:	learn: 656.9405314	total: 39.9s	remaining: 1m 14s
# 122:	learn: 655.2592197	total: 40.2s	remaining: 1m 14s
# 123:	learn: 653.5961124	total: 40.5s	remaining: 1m 13s
# 124:	learn: 652.1336587	total: 40.9s	remaining: 1m 13s
# 125:	learn: 651.3380901	total: 41.2s	remaining: 1m 13s
# 126:	learn: 650.1077844	total: 41.5s	remaining: 1m 12s
# 127:	learn: 648.3367488	total: 41.8s	remaining: 1m 12s
# 128:	learn: 645.6455918	total: 42.1s	remaining: 1m 12s
# 129:	learn: 644.6193970	total: 42.4s	remaining: 1m 11s
# 130:	learn: 642.5396441	total: 42.8s	remaining: 1m 11s
# 131:	learn: 642.2152565	total: 43.1s	remaining: 1m 11s
# 132:	learn: 640.9492466	total: 43.4s	remaining: 1m 10s
# 133:	learn: 640.3730287	total: 43.7s	remaining: 1m 10s
# 134:	learn: 638.4732436	total: 44s	remaining: 1m 10s
# 135:	learn: 637.1586472	total: 44.4s	remaining: 1m 9s
# 136:	learn: 634.9872314	total: 44.7s	remaining: 1m 9s
# 137:	learn: 633.3449218	total: 45s	remaining: 1m 9s
# 138:	learn: 632.0753514	total: 45.3s	remaining: 1m 8s
# 139:	learn: 631.7067551	total: 45.6s	remaining: 1m 8s
# 140:	learn: 629.7228087	total: 45.9s	remaining: 1m 8s
# 141:	learn: 629.3517691	total: 46.3s	remaining: 1m 7s
# 142:	learn: 627.9280547	total: 46.6s	remaining: 1m 7s
# 143:	learn: 626.8058857	total: 46.9s	remaining: 1m 7s
# 144:	learn: 626.0282446	total: 47.3s	remaining: 1m 6s
# 145:	learn: 625.7068061	total: 47.6s	remaining: 1m 6s
# 146:	learn: 625.3164980	total: 47.9s	remaining: 1m 6s
# 147:	learn: 624.8114562	total: 48.2s	remaining: 1m 5s
# 148:	learn: 622.6482620	total: 48.5s	remaining: 1m 5s
# 149:	learn: 620.3847619	total: 48.8s	remaining: 1m 5s
# 150:	learn: 618.2592808	total: 49.2s	remaining: 1m 4s
# 151:	learn: 616.0756789	total: 49.5s	remaining: 1m 4s
# 152:	learn: 615.1071788	total: 49.8s	remaining: 1m 4s
# 153:	learn: 613.8250738	total: 50.1s	remaining: 1m 3s
# 154:	learn: 613.1914992	total: 50.4s	remaining: 1m 3s
# 155:	learn: 612.4628604	total: 50.7s	remaining: 1m 3s
# 156:	learn: 611.9966574	total: 51.1s	remaining: 1m 2s
# 157:	learn: 611.1240102	total: 51.4s	remaining: 1m 2s
# 158:	learn: 610.5887166	total: 51.7s	remaining: 1m 2s
# 159:	learn: 609.4556022	total: 52s	remaining: 1m 1s
# 160:	learn: 609.1214519	total: 52.3s	remaining: 1m 1s
# 161:	learn: 608.6964295	total: 52.6s	remaining: 1m 1s
# 162:	learn: 607.5694727	total: 52.9s	remaining: 1m
# 163:	learn: 606.9213391	total: 53.2s	remaining: 1m
# 164:	learn: 605.0865483	total: 53.5s	remaining: 1m
# 165:	learn: 604.2144412	total: 53.9s	remaining: 59.7s
# 166:	learn: 602.9327284	total: 54.2s	remaining: 59.4s
# 167:	learn: 601.9890437	total: 54.5s	remaining: 59s
# 168:	learn: 600.5611664	total: 54.8s	remaining: 58.7s
# 169:	learn: 599.9799234	total: 55.1s	remaining: 58.3s
# 170:	learn: 599.3896583	total: 55.4s	remaining: 58s
# 171:	learn: 598.0082038	total: 55.8s	remaining: 57.7s
# 172:	learn: 596.5430134	total: 56.1s	remaining: 57.4s
# 173:	learn: 596.0309738	total: 56.4s	remaining: 57s
# 174:	learn: 595.0570122	total: 56.7s	remaining: 56.7s
# 175:	learn: 594.7370108	total: 57.1s	remaining: 56.4s
# 176:	learn: 593.7246645	total: 57.4s	remaining: 56.1s
# 177:	learn: 593.2049895	total: 57.7s	remaining: 55.8s
# 178:	learn: 592.4744480	total: 58s	remaining: 55.4s
# 179:	learn: 592.1782679	total: 58.3s	remaining: 55.1s
# 180:	learn: 591.2955724	total: 58.6s	remaining: 54.8s
# 181:	learn: 589.6364607	total: 59s	remaining: 54.4s
# 182:	learn: 589.2046092	total: 59.3s	remaining: 54.1s
# 183:	learn: 587.7772324	total: 59.6s	remaining: 53.8s
# 184:	learn: 586.1054049	total: 59.9s	remaining: 53.5s
# 185:	learn: 585.7503613	total: 1m	remaining: 53.1s
# 186:	learn: 585.0134114	total: 1m	remaining: 52.8s
# 187:	learn: 584.6876166	total: 1m	remaining: 52.5s
# 188:	learn: 584.3517424	total: 1m 1s	remaining: 52.1s
# 189:	learn: 582.6316849	total: 1m 1s	remaining: 51.8s
# 190:	learn: 581.8529967	total: 1m 1s	remaining: 51.5s
# 191:	learn: 581.5175648	total: 1m 2s	remaining: 51.2s
# 192:	learn: 580.3539499	total: 1m 2s	remaining: 50.9s
# 193:	learn: 579.6646453	total: 1m 2s	remaining: 50.5s
# 194:	learn: 578.4670922	total: 1m 3s	remaining: 50.2s
# 195:	learn: 577.8585070	total: 1m 3s	remaining: 49.9s
# 196:	learn: 577.3490278	total: 1m 3s	remaining: 49.6s
# 197:	learn: 576.0352675	total: 1m 4s	remaining: 49.3s
# 198:	learn: 575.6303621	total: 1m 4s	remaining: 49s
# 199:	learn: 575.3415073	total: 1m 4s	remaining: 48.7s
# 200:	learn: 574.8356483	total: 1m 5s	remaining: 48.4s
# 201:	learn: 574.6305239	total: 1m 5s	remaining: 48.1s
# 202:	learn: 573.8643712	total: 1m 6s	remaining: 47.8s
# 203:	learn: 572.9668631	total: 1m 6s	remaining: 47.5s
# 204:	learn: 572.3225347	total: 1m 6s	remaining: 47.2s
# 205:	learn: 571.5739514	total: 1m 7s	remaining: 46.8s
# 206:	learn: 571.2276875	total: 1m 7s	remaining: 46.5s
# 207:	learn: 570.9476985	total: 1m 7s	remaining: 46.2s
# 208:	learn: 570.6022789	total: 1m 7s	remaining: 45.9s
# 209:	learn: 569.7887956	total: 1m 8s	remaining: 45.5s
# 210:	learn: 568.9431585	total: 1m 8s	remaining: 45.2s
# 211:	learn: 568.4115186	total: 1m 8s	remaining: 44.9s
# 212:	learn: 567.3709568	total: 1m 9s	remaining: 44.6s
# 213:	learn: 566.7467102	total: 1m 9s	remaining: 44.3s
# 214:	learn: 566.5045251	total: 1m 10s	remaining: 44s
# 215:	learn: 566.1362753	total: 1m 10s	remaining: 43.7s
# 216:	learn: 565.8271239	total: 1m 10s	remaining: 43.4s
# 217:	learn: 563.9999865	total: 1m 11s	remaining: 43s
# 218:	learn: 563.5722785	total: 1m 11s	remaining: 42.8s
# 219:	learn: 563.3738140	total: 1m 11s	remaining: 42.4s
# 220:	learn: 562.8550872	total: 1m 12s	remaining: 42.1s
# 221:	learn: 561.4381305	total: 1m 12s	remaining: 41.8s
# 222:	learn: 561.1193107	total: 1m 12s	remaining: 41.5s
# 223:	learn: 560.6900551	total: 1m 13s	remaining: 41.2s
# 224:	learn: 559.4440961	total: 1m 13s	remaining: 40.9s
# 225:	learn: 558.5969016	total: 1m 13s	remaining: 40.5s
# 226:	learn: 558.2333866	total: 1m 14s	remaining: 40.2s
# 227:	learn: 557.0842536	total: 1m 14s	remaining: 39.9s
# 228:	learn: 556.9115734	total: 1m 14s	remaining: 39.5s
# 229:	learn: 556.5257859	total: 1m 15s	remaining: 39.2s
# 230:	learn: 555.9854458	total: 1m 15s	remaining: 38.9s
# 231:	learn: 555.1353839	total: 1m 15s	remaining: 38.5s
# 232:	learn: 554.9672350	total: 1m 16s	remaining: 38.2s
# 233:	learn: 554.2123374	total: 1m 16s	remaining: 37.9s
# 234:	learn: 553.9454638	total: 1m 16s	remaining: 37.5s
# 235:	learn: 552.8480370	total: 1m 17s	remaining: 37.2s
# 236:	learn: 552.6678319	total: 1m 17s	remaining: 36.9s
# 237:	learn: 551.6484583	total: 1m 17s	remaining: 36.5s
# 238:	learn: 551.3326242	total: 1m 17s	remaining: 36.2s
# 239:	learn: 549.5876777	total: 1m 18s	remaining: 35.9s
# 240:	learn: 549.2468561	total: 1m 18s	remaining: 35.6s
# 241:	learn: 547.5801638	total: 1m 18s	remaining: 35.2s
# 242:	learn: 547.2246362	total: 1m 19s	remaining: 34.9s
# 243:	learn: 546.5329790	total: 1m 19s	remaining: 34.6s
# 244:	learn: 546.3092055	total: 1m 19s	remaining: 34.3s
# 245:	learn: 545.2116147	total: 1m 20s	remaining: 33.9s
# 246:	learn: 544.5286607	total: 1m 20s	remaining: 33.7s
# 247:	learn: 543.7598639	total: 1m 21s	remaining: 33.4s
# 248:	learn: 543.2768646	total: 1m 21s	remaining: 33s
# 249:	learn: 542.8430202	total: 1m 21s	remaining: 32.7s
# 250:	learn: 541.7452080	total: 1m 22s	remaining: 32.4s
# 251:	learn: 541.4456953	total: 1m 22s	remaining: 32.2s
# 252:	learn: 541.1436924	total: 1m 23s	remaining: 31.9s
# 253:	learn: 540.8654590	total: 1m 23s	remaining: 31.6s
# 254:	learn: 540.6127184	total: 1m 24s	remaining: 31.3s
# 255:	learn: 540.2601716	total: 1m 24s	remaining: 31s
# 256:	learn: 539.7188870	total: 1m 24s	remaining: 30.7s
# 257:	learn: 538.7650848	total: 1m 25s	remaining: 30.4s
# 258:	learn: 538.3088119	total: 1m 25s	remaining: 30.1s
# 259:	learn: 537.7992812	total: 1m 25s	remaining: 29.7s
# 260:	learn: 537.5853876	total: 1m 26s	remaining: 29.4s
# 261:	learn: 536.4573719	total: 1m 26s	remaining: 29.1s
# 262:	learn: 536.1613378	total: 1m 26s	remaining: 28.8s
# 263:	learn: 535.7144299	total: 1m 27s	remaining: 28.4s
# 264:	learn: 535.5447146	total: 1m 27s	remaining: 28.1s
# 265:	learn: 535.3020344	total: 1m 27s	remaining: 27.8s
# 266:	learn: 535.0167133	total: 1m 28s	remaining: 27.4s
# 267:	learn: 533.9311482	total: 1m 28s	remaining: 27.1s
# 268:	learn: 533.3956471	total: 1m 28s	remaining: 26.8s
# 269:	learn: 533.1932092	total: 1m 29s	remaining: 26.4s
# 270:	learn: 533.0158427	total: 1m 29s	remaining: 26.1s
# 271:	learn: 532.7857868	total: 1m 30s	remaining: 25.8s
# 272:	learn: 532.6253692	total: 1m 30s	remaining: 25.6s
# 273:	learn: 532.4255462	total: 1m 31s	remaining: 25.3s
# 274:	learn: 532.2864691	total: 1m 31s	remaining: 25s
# 275:	learn: 532.1133277	total: 1m 32s	remaining: 24.7s
# 276:	learn: 531.9457590	total: 1m 32s	remaining: 24.4s
# 277:	learn: 531.6260968	total: 1m 32s	remaining: 24s
# 278:	learn: 531.4436007	total: 1m 33s	remaining: 23.7s
# 279:	learn: 531.2304678	total: 1m 33s	remaining: 23.4s
# 280:	learn: 530.6269508	total: 1m 33s	remaining: 23s
# 281:	learn: 530.3390975	total: 1m 34s	remaining: 22.7s
# 282:	learn: 530.1244182	total: 1m 34s	remaining: 22.4s
# 283:	learn: 529.5155697	total: 1m 34s	remaining: 22s
# 284:	learn: 529.3481917	total: 1m 35s	remaining: 21.7s
# 285:	learn: 529.0580230	total: 1m 35s	remaining: 21.4s
# 286:	learn: 528.8917010	total: 1m 35s	remaining: 21s
# 287:	learn: 528.2036140	total: 1m 36s	remaining: 20.7s
# 288:	learn: 528.0242855	total: 1m 36s	remaining: 20.3s
# 289:	learn: 527.1780718	total: 1m 36s	remaining: 20s
# 290:	learn: 526.8829500	total: 1m 37s	remaining: 19.7s
# 291:	learn: 526.3819496	total: 1m 37s	remaining: 19.3s
# 292:	learn: 526.2476778	total: 1m 37s	remaining: 19s
# 293:	learn: 525.1204630	total: 1m 38s	remaining: 18.7s
# 294:	learn: 524.0621638	total: 1m 38s	remaining: 18.3s
# 295:	learn: 522.9875176	total: 1m 38s	remaining: 18s
# 296:	learn: 522.2705454	total: 1m 39s	remaining: 17.7s
# 297:	learn: 522.0392464	total: 1m 39s	remaining: 17.4s
# 298:	learn: 521.4955606	total: 1m 39s	remaining: 17s
# 299:	learn: 520.6079817	total: 1m 40s	remaining: 16.7s
# 300:	learn: 520.1786808	total: 1m 40s	remaining: 16.4s
# 301:	learn: 519.9356446	total: 1m 40s	remaining: 16s
# 302:	learn: 519.6698064	total: 1m 41s	remaining: 15.7s
# 303:	learn: 519.0558905	total: 1m 41s	remaining: 15.4s
# 304:	learn: 518.8435408	total: 1m 41s	remaining: 15s
# 305:	learn: 518.3994631	total: 1m 42s	remaining: 14.7s
# 306:	learn: 517.9287617	total: 1m 42s	remaining: 14.4s
# 307:	learn: 517.2360840	total: 1m 42s	remaining: 14s
# 308:	learn: 516.4557144	total: 1m 43s	remaining: 13.7s
# 309:	learn: 515.8751211	total: 1m 43s	remaining: 13.4s
# 310:	learn: 514.9712316	total: 1m 44s	remaining: 13.1s
# 311:	learn: 514.2162500	total: 1m 44s	remaining: 12.7s
# 312:	learn: 513.9682570	total: 1m 44s	remaining: 12.4s
# 313:	learn: 513.2874266	total: 1m 45s	remaining: 12.1s
# 314:	learn: 512.7567601	total: 1m 45s	remaining: 11.7s
# 315:	learn: 511.9653275	total: 1m 46s	remaining: 11.4s
# 316:	learn: 511.7794711	total: 1m 46s	remaining: 11.1s
# 317:	learn: 511.6368310	total: 1m 47s	remaining: 10.8s
# 318:	learn: 511.1425590	total: 1m 47s	remaining: 10.5s
# 319:	learn: 510.7780096	total: 1m 48s	remaining: 10.1s
# 320:	learn: 510.6075675	total: 1m 48s	remaining: 9.8s
# 321:	learn: 510.1363654	total: 1m 48s	remaining: 9.47s
# 322:	learn: 509.9728548	total: 1m 49s	remaining: 9.14s
# 323:	learn: 509.4140463	total: 1m 49s	remaining: 8.81s
# 324:	learn: 508.5566160	total: 1m 50s	remaining: 8.48s
# 325:	learn: 508.1313933	total: 1m 50s	remaining: 8.14s
# 326:	learn: 507.1800558	total: 1m 50s	remaining: 7.8s
# 327:	learn: 506.5125653	total: 1m 51s	remaining: 7.46s
# 328:	learn: 506.1888454	total: 1m 51s	remaining: 7.13s
# 329:	learn: 505.5540240	total: 1m 51s	remaining: 6.79s
# 330:	learn: 505.2132177	total: 1m 52s	remaining: 6.45s
# 331:	learn: 505.0018418	total: 1m 52s	remaining: 6.11s
# 332:	learn: 504.7585007	total: 1m 53s	remaining: 5.77s
# 333:	learn: 504.3182956	total: 1m 53s	remaining: 5.44s
# 334:	learn: 503.7961182	total: 1m 53s	remaining: 5.1s
# 335:	learn: 503.5882305	total: 1m 54s	remaining: 4.76s
# 336:	learn: 503.1283283	total: 1m 54s	remaining: 4.42s
# 337:	learn: 502.5001959	total: 1m 54s	remaining: 4.08s
# 338:	learn: 502.4198568	total: 1m 55s	remaining: 3.74s
# 339:	learn: 502.1755364	total: 1m 55s	remaining: 3.4s
# 340:	learn: 501.9152590	total: 1m 55s	remaining: 3.06s
# 341:	learn: 501.7123239	total: 1m 56s	remaining: 2.72s
# 342:	learn: 501.5416558	total: 1m 56s	remaining: 2.38s
# 343:	learn: 501.4899848	total: 1m 56s	remaining: 2.04s
# 344:	learn: 500.9359283	total: 1m 57s	remaining: 1.7s
# 345:	learn: 500.5926759	total: 1m 57s	remaining: 1.36s
# 346:	learn: 500.2702092	total: 1m 57s	remaining: 1.02s
# 347:	learn: 499.4766843	total: 1m 58s	remaining: 680ms
# 348:	learn: 498.7288746	total: 1m 58s	remaining: 340ms
# 349:	learn: 498.5289372	total: 1m 59s	remaining: 0us
# MAE with catboost: 507.4080634122852
# Predict catboost ...
# Catboost Done!

# %% [markdown]
# ### 使用xgboost模型

# %%
# 使用xgb对数据2进行训练与预测


X_train = Train_data_2.drop(['SaleID', 'price'], axis=1)
Y_train = Train_data_2['price']

X_test = Test_data_2.drop('SaleID', axis=1)
res_xgb_1 = pd.DataFrame()
res_xgb_1['SaleID'] = Test_data_2['SaleID']


print('Train xgboost ...')
model_xgb_1 = build_model_xgb_1(X_train, Y_train)
val_xgb_1 = model_xgb_1.predict(X_train)
MAE_xgb_1 = mean_absolute_error(Y_train, val_xgb_1)
print('MAE with xgboost:' ,MAE_xgb_1)

print('Predict xgboost ...')
res_xgb_1['price'] = model_xgb_1.predict(X_test)
print('Xgboost Done!')
# Out:
# Train xgboost ...
# [10:24:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# MAE with xgboost: 220.7082378428163
# Predict xgboost ...
# Xgboost Done!

# %%
# 使用xgb对数据3进行训练与预测

X_train = Train_data_3.drop(['SaleID', 'price'], axis=1)
Y_train = Train_data_3['price']

X_test = Test_data_3.drop('SaleID', axis=1)
res_xgb_2 = pd.DataFrame()
res_xgb_2['SaleID'] = Test_data_3['SaleID']


print('Train xgboost ...')
model_xgb_2 = build_model_xgb_2(X_train, Y_train)
val_xgb_2 = model_xgb_2.predict(X_train)
MAE_xgb_2 = mean_absolute_error(Y_train, val_xgb_2)
print('MAE with xgboost:' ,MAE_xgb_2)

print('Predict xgboost ...')
res_xgb_2['price'] = model_xgb_2.predict(X_test)
print('Xgboost Done!')
# Out:
# Train xgboost ...
# [10:27:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# c:\users\xyao\envs\learnpy\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# MAE with xgboost: 12.582586533195219
# Predict xgboost ...
# Xgboost Done!

# %% [markdown]
# ### 使用lightgbm模型

# %%
# 使用lgb对数据2进行训练与预测

X_train = Train_data_2.drop(['SaleID', 'price'], axis=1)
Y_train = Train_data_2['price']

X_test = Test_data_2.drop('SaleID', axis=1)
res_lgb_1 = pd.DataFrame()
res_lgb_1['SaleID'] = Test_data_2['SaleID']


print('Train lgb ...')
model_lgb_1 = build_model_lgb_1(X_train, Y_train)
val_lgb_1 = model_lgb_1.predict(X_train)
MAE_lgb_1 = mean_absolute_error(Y_train, val_lgb_1)
print('MAE with lgb:' ,MAE_lgb_1)

print('Predict lgb ...')
res_lgb_1['price'] = model_lgb_1.predict(X_test)
print('Lgb Done!')
# Out:
# Train lgb ...
# MAE with lgb: 528.182895551685
# Predict lgb ...
# Lgb Done!

# %%
# 使用lgb对数据3进行训练与预测

X_train = Train_data_3.drop(['SaleID', 'price'], axis=1)
Y_train = Train_data_3['price']

X_test = Test_data_3.drop('SaleID', axis=1)
res_lgb_2 = pd.DataFrame()
res_lgb_2['SaleID'] = Test_data_3['SaleID']


print('Train lgb ...')
model_lgb_2 = build_model_lgb_2(X_train, Y_train)
val_lgb_2 = model_lgb_2.predict(X_train)
MAE_lgb_2 = mean_absolute_error(Y_train, val_lgb_2)
print('MAE with lgb:' ,MAE_lgb_2)

print('Predict lgb ...')
res_lgb_2['price'] = model_lgb_2.predict(X_test)
print('Lgb Done!')
# Out:
# Train lgb ...
# MAE with lgb: 137.66646124469548
# Predict lgb ...
# Lgb Done!

# %% [markdown]
# ### 合并结果

# %% [markdown]
# 简单地进行加权融合，未使用stacking。

# %%
res_cat
# Out:
#        SaleID         price
# 0      150000  34401.554304
# 1      150001    313.837032
# 2      150002   6961.440489
# 3      150003  12732.420952
# 4      150004    598.709913
# ...       ...           ...
# 49995  199995   2963.090160
# 49996  199996   1194.045108
# 49997  199997   7796.021608
# 49998  199998   9057.747874
# 49999  199999   3400.020182
#
# [50000 rows x 2 columns]

# %%
res_xgb = pd.concat([res_xgb_1, res_xgb_2], axis=0)
res_xgb.sort_values('SaleID', inplace=True)

# %%
res_xgb
# Out:
#        SaleID         price
# 0      150000  38791.167969
# 1      150001    290.022827
# 2      150002   6402.432617
# 3      150003  11093.931641
# 4      150004    646.546143
# ...       ...           ...
# 49995  199995   1890.720703
# 49996  199996   1531.341919
# 49997  199997   8753.550781
# 49998  199998   8672.522461
# 49999  199999   3684.457031
#
# [50000 rows x 2 columns]

# %%
res_xgb['price'] = res_xgb['price'].apply(lambda x: 10 if x<10 else x)

# %%
res_xgb.to_csv('res_xgb.csv', index=False)

# %%
res_xgb['price'].describe()
# Out:
# count    50000.000000
# mean      5926.376987
# std       7399.875033
# min         10.000000
# 25%       1365.219940
# 50%       3263.214111
# 75%       7693.387451
# max      94094.398438
# Name: price, dtype: float64

# %%
Train_data['price'].describe()
# Out:
# count    150000.000000
# mean       5923.327333
# std        7501.998477
# min          11.000000
# 25%        1300.000000
# 50%        3250.000000
# 75%        7700.000000
# max       99999.000000
# Name: price, dtype: float64

# %%
res_lgb = pd.concat([res_lgb_1, res_lgb_2], axis=0)
res_lgb.sort_values('SaleID', inplace=True)
# Out:
# c:\users\xyao\envs\learnpy\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %%
res_lgb
# Out:
#        SaleID         price       price_1     price_2
# 0      150000  38640.667360  11387.921718         NaN
# 1      150001    422.646556    124.559595         NaN
# 2      150002   7859.604011   2316.330470         NaN
# 3      150003  11711.598416   3451.564765         NaN
# 4      150004    612.125190    180.401484         NaN
# ...       ...           ...           ...         ...
# 49995  199995   1975.274935    582.139954         NaN
# 49996  199996   1499.053153    441.791023         NaN
# 49997  199997   7937.583677   2339.312122         NaN
# 49998  199998   8014.409505           NaN  671.165659
# 49999  199999   3412.770559   1005.789150         NaN
#
# [50000 rows x 4 columns]

# %%
res = pd.DataFrame()
res['SaleID'] = TestA_data['SaleID']
weight_cat = ((2/3) - MAE_cat/(MAE_cat + (MAE_lgb_1+MAE_lgb_2)/2 + (MAE_xgb_1+MAE_xgb_2)/2))
weight_xgb = ((2/3)- ((MAE_xgb_1+MAE_xgb_2)/2)/(MAE_cat + (MAE_lgb_1+MAE_lgb_2)/2 + (MAE_xgb_1+MAE_xgb_2)/2))
weight_lgb = ((2/3)- ((MAE_lgb_1+MAE_lgb_2)/2)/(MAE_cat + (MAE_lgb_1+MAE_lgb_2)/2 + (MAE_xgb_1+MAE_xgb_2)/2))

res['price'] = weight_cat * res_cat['price'] + weight_lgb * res_lgb['price'] + weight_xgb * res_xgb['price']

# %%
res
# Out:
#        SaleID         price
# 0      150000  38144.238975
# 1      150001    335.549350
# 2      150002   6943.217646
# 3      150003  11514.396295
# 4      150004    629.046462
# ...       ...           ...
# 49995  199995   2063.996634
# 49996  199996   1475.025688
# 49997  199997   8362.787903
# 49998  199998   8515.295491
# 49999  199999   3559.039314
#
# [50000 rows x 2 columns]

# %%
res['price'].describe()
# Out:
# count    50000.000000
# mean      5918.478760
# std       7374.641035
# min       -260.398814
# 25%       1374.223368
# 50%       3256.042068
# 75%       7691.492944
# max      93072.824468
# Name: price, dtype: float64

# %%
res['price'] = res['price'].apply(lambda x: 10 if x<10 else x)

# %%
res['price'].describe()
# Out:
# count    50000.000000
# mean      5918.505537
# std       7374.619304
# min         10.000000
# 25%       1374.223368
# 50%       3256.042068
# 75%       7691.492944
# max      93072.824468
# Name: price, dtype: float64

# %%
res.to_csv('sub_10.csv',index=False)
